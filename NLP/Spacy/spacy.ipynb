# %% [markdown]
# # Inicilizar com SPACY

# %% [markdown]
# ## Baixar o Modelo em Português

# %%
# !python -m spacy download "pt_core_news_lg"
# Out:
# Collecting pt-core-news-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.6.0/pt_core_news_lg-3.6.0-py3-none-any.whl (568.2 MB)
#      ---------------------------------------- 0.0/568.2 MB ? eta -:--:--
#      -------------------------------------- 0.0/568.2 MB 660.6 kB/s eta 0:14:21
#      ---------------------------------------- 0.1/568.2 MB 1.1 MB/s eta 0:09:01
#      ---------------------------------------- 0.3/568.2 MB 2.2 MB/s eta 0:04:17
#      ---------------------------------------- 1.1/568.2 MB 6.1 MB/s eta 0:01:33
#      --------------------------------------- 3.4/568.2 MB 15.3 MB/s eta 0:00:37
#      --------------------------------------- 5.9/568.2 MB 22.4 MB/s eta 0:00:26
#       -------------------------------------- 8.6/568.2 MB 27.6 MB/s eta 0:00:21
#       ------------------------------------- 11.6/568.2 MB 59.5 MB/s eta 0:00:10
#       ------------------------------------- 14.4/568.2 MB 59.5 MB/s eta 0:00:10
#      - ------------------------------------ 15.8/568.2 MB 54.4 MB/s eta 0:00:11
#      - ------------------------------------ 16.8/568.2 MB 54.4 MB/s eta 0:00:11
#      - ------------------------------------ 19.0/568.2 MB 43.5 MB/s eta 0:00:13
#      - ------------------------------------ 21.2/568.2 MB 43.5 MB/s eta 0:00:13
#      - ------------------------------------ 23.8/568.2 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 24.0/568.2 MB 36.4 MB/s eta 0:00:15
#      - ------------------------------------ 25.7/568.2 MB 36.4 MB/s eta 0:00:15
#      - ------------------------------------ 28.0/568.2 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 28.4/568.2 MB 34.4 MB/s eta 0:00:16
#      - ------------------------------------ 29.8/568.2 MB 32.7 MB/s eta 0:00:17
#      -- ----------------------------------- 32.3/568.2 MB 32.7 MB/s eta 0:00:17
#      -- ----------------------------------- 35.1/568.2 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 36.3/568.2 MB 40.9 MB/s eta 0:00:13
#      -- ----------------------------------- 37.8/568.2 MB 34.4 MB/s eta 0:00:16
#      -- ----------------------------------- 40.4/568.2 MB 46.7 MB/s eta 0:00:12
#      -- ----------------------------------- 40.6/568.2 MB 38.5 MB/s eta 0:00:14
#      -- ----------------------------------- 42.5/568.2 MB 36.4 MB/s eta 0:00:15
#      -- ----------------------------------- 43.8/568.2 MB 34.4 MB/s eta 0:00:16
#      --- ---------------------------------- 45.7/568.2 MB 32.8 MB/s eta 0:00:16
#      --- ---------------------------------- 48.6/568.2 MB 36.3 MB/s eta 0:00:15
#      --- ---------------------------------- 48.9/568.2 MB 32.8 MB/s eta 0:00:16
#      --- ---------------------------------- 50.4/568.2 MB 29.8 MB/s eta 0:00:18
#      --- ---------------------------------- 52.3/568.2 MB 36.3 MB/s eta 0:00:15
#      --- ---------------------------------- 54.3/568.2 MB 36.4 MB/s eta 0:00:15
#      --- ---------------------------------- 57.0/568.2 MB 40.9 MB/s eta 0:00:13
#      --- ---------------------------------- 57.2/568.2 MB 34.4 MB/s eta 0:00:15
#      --- ---------------------------------- 59.5/568.2 MB 38.5 MB/s eta 0:00:14
#      ---- --------------------------------- 61.2/568.2 MB 43.7 MB/s eta 0:00:12
#      ---- --------------------------------- 62.1/568.2 MB 36.4 MB/s eta 0:00:14
#      ---- --------------------------------- 64.6/568.2 MB 38.5 MB/s eta 0:00:14
#      ---- --------------------------------- 65.3/568.2 MB 38.6 MB/s eta 0:00:14
#      ---- --------------------------------- 67.7/568.2 MB 38.6 MB/s eta 0:00:13
#      ---- --------------------------------- 69.5/568.2 MB 38.5 MB/s eta 0:00:13
#      ---- --------------------------------- 70.7/568.2 MB 34.4 MB/s eta 0:00:15
#      ---- --------------------------------- 72.2/568.2 MB 36.4 MB/s eta 0:00:14
#      ---- --------------------------------- 73.7/568.2 MB 34.4 MB/s eta 0:00:15
#      ----- -------------------------------- 75.8/568.2 MB 38.5 MB/s eta 0:00:13
#      ----- -------------------------------- 77.5/568.2 MB 38.5 MB/s eta 0:00:13
#      ----- -------------------------------- 78.6/568.2 MB 32.7 MB/s eta 0:00:15
#      ----- -------------------------------- 81.3/568.2 MB 38.6 MB/s eta 0:00:13
#      ----- -------------------------------- 82.0/568.2 MB 38.5 MB/s eta 0:00:13
#      ----- -------------------------------- 83.1/568.2 MB 32.8 MB/s eta 0:00:15
#      ----- -------------------------------- 83.7/568.2 MB 32.7 MB/s eta 0:00:15
#      ----- -------------------------------- 86.3/568.2 MB 31.2 MB/s eta 0:00:16
#      ----- -------------------------------- 89.0/568.2 MB 36.4 MB/s eta 0:00:14
#      ------ ------------------------------- 90.3/568.2 MB 32.7 MB/s eta 0:00:15
#      ------ ------------------------------- 92.6/568.2 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------- 94.5/568.2 MB 46.7 MB/s eta 0:00:11
#      ------ ------------------------------- 95.3/568.2 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------- 98.1/568.2 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------- 98.6/568.2 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------ 100.8/568.2 MB 38.6 MB/s eta 0:00:13
#      ------ ------------------------------ 102.0/568.2 MB 36.4 MB/s eta 0:00:13
#      ------ ------------------------------ 103.4/568.2 MB 32.8 MB/s eta 0:00:15
#      ------ ------------------------------ 105.6/568.2 MB 38.5 MB/s eta 0:00:13
#      ------ ------------------------------ 106.9/568.2 MB 36.4 MB/s eta 0:00:13
#      ------- ----------------------------- 108.3/568.2 MB 32.8 MB/s eta 0:00:15
#      ------- ----------------------------- 110.4/568.2 MB 36.3 MB/s eta 0:00:13
#      ------- ----------------------------- 111.9/568.2 MB 36.4 MB/s eta 0:00:13
#      ------- ----------------------------- 114.9/568.2 MB 40.9 MB/s eta 0:00:12
#      ------- ----------------------------- 115.3/568.2 MB 36.4 MB/s eta 0:00:13
#      ------- ----------------------------- 116.2/568.2 MB 34.6 MB/s eta 0:00:14
#      ------- ----------------------------- 119.0/568.2 MB 40.9 MB/s eta 0:00:11
#      ------- ----------------------------- 120.5/568.2 MB 36.4 MB/s eta 0:00:13
#      -------- ---------------------------- 123.5/568.2 MB 40.9 MB/s eta 0:00:11
#      -------- ---------------------------- 123.6/568.2 MB 34.4 MB/s eta 0:00:13
#      -------- ---------------------------- 126.2/568.2 MB 38.6 MB/s eta 0:00:12
#      -------- ---------------------------- 127.7/568.2 MB 43.5 MB/s eta 0:00:11
#      -------- ---------------------------- 128.7/568.2 MB 36.4 MB/s eta 0:00:13
#      -------- ---------------------------- 131.6/568.2 MB 38.5 MB/s eta 0:00:12
#      -------- ---------------------------- 131.8/568.2 MB 34.4 MB/s eta 0:00:13
#      -------- ---------------------------- 133.6/568.2 MB 31.2 MB/s eta 0:00:14
#      -------- ---------------------------- 135.3/568.2 MB 34.4 MB/s eta 0:00:13
#      -------- ---------------------------- 137.0/568.2 MB 32.7 MB/s eta 0:00:14
#      --------- --------------------------- 139.7/568.2 MB 38.6 MB/s eta 0:00:12
#      --------- --------------------------- 140.1/568.2 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 142.3/568.2 MB 38.6 MB/s eta 0:00:12
#      --------- --------------------------- 144.3/568.2 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 145.3/568.2 MB 36.4 MB/s eta 0:00:12
#      --------- --------------------------- 148.2/568.2 MB 38.5 MB/s eta 0:00:11
#      --------- --------------------------- 148.4/568.2 MB 32.7 MB/s eta 0:00:13
#      --------- --------------------------- 150.9/568.2 MB 38.5 MB/s eta 0:00:11
#      --------- --------------------------- 152.6/568.2 MB 38.5 MB/s eta 0:00:11
#      ---------- -------------------------- 153.7/568.2 MB 32.8 MB/s eta 0:00:13
#      ---------- -------------------------- 156.0/568.2 MB 38.6 MB/s eta 0:00:11
#      ---------- -------------------------- 156.8/568.2 MB 32.8 MB/s eta 0:00:13
#      ---------- -------------------------- 159.1/568.2 MB 38.5 MB/s eta 0:00:11
#      ---------- -------------------------- 160.9/568.2 MB 38.6 MB/s eta 0:00:11
#      ---------- -------------------------- 162.1/568.2 MB 32.7 MB/s eta 0:00:13
#      ---------- -------------------------- 164.7/568.2 MB 38.5 MB/s eta 0:00:11
#      ---------- -------------------------- 165.2/568.2 MB 34.6 MB/s eta 0:00:12
#      ---------- -------------------------- 167.7/568.2 MB 38.6 MB/s eta 0:00:11
#      ----------- ------------------------- 169.2/568.2 MB 40.9 MB/s eta 0:00:10
#      ----------- ------------------------- 170.4/568.2 MB 32.8 MB/s eta 0:00:13
#      ----------- ------------------------- 173.2/568.2 MB 38.5 MB/s eta 0:00:11
#      ----------- ------------------------- 173.5/568.2 MB 32.7 MB/s eta 0:00:13
#      ----------- ------------------------- 175.6/568.2 MB 38.5 MB/s eta 0:00:11
#      ----------- ------------------------- 177.5/568.2 MB 36.4 MB/s eta 0:00:11
#      ----------- ------------------------- 178.3/568.2 MB 32.7 MB/s eta 0:00:12
#      ----------- ------------------------- 181.1/568.2 MB 38.5 MB/s eta 0:00:11
#      ----------- ------------------------- 181.7/568.2 MB 34.4 MB/s eta 0:00:12
#      ----------- ------------------------- 183.6/568.2 MB 36.4 MB/s eta 0:00:11
#      ------------ ------------------------ 185.8/568.2 MB 38.5 MB/s eta 0:00:10
#      ------------ ------------------------ 186.4/568.2 MB 32.8 MB/s eta 0:00:12
#      ------------ ------------------------ 188.4/568.2 MB 36.4 MB/s eta 0:00:11
#      ------------ ------------------------ 190.0/568.2 MB 34.4 MB/s eta 0:00:11
#      ------------ ------------------------ 192.4/568.2 MB 38.5 MB/s eta 0:00:10
#      ------------ ------------------------ 194.1/568.2 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 195.2/568.2 MB 34.4 MB/s eta 0:00:11
#      ------------ ------------------------ 198.0/568.2 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 198.3/568.2 MB 36.4 MB/s eta 0:00:11
#      ------------- ----------------------- 200.6/568.2 MB 38.6 MB/s eta 0:00:10
#      ------------- ----------------------- 202.4/568.2 MB 38.6 MB/s eta 0:00:10
#      ------------- ----------------------- 203.5/568.2 MB 32.7 MB/s eta 0:00:12
#      ------------- ----------------------- 206.0/568.2 MB 38.5 MB/s eta 0:00:10
#      ------------- ----------------------- 206.6/568.2 MB 34.4 MB/s eta 0:00:11
#      ------------- ----------------------- 209.1/568.2 MB 38.5 MB/s eta 0:00:10
#      ------------- ----------------------- 210.7/568.2 MB 38.5 MB/s eta 0:00:10
#      ------------- ----------------------- 211.7/568.2 MB 32.8 MB/s eta 0:00:11
#      ------------- ----------------------- 214.1/568.2 MB 38.6 MB/s eta 0:00:10
#      ------------- ----------------------- 214.9/568.2 MB 32.8 MB/s eta 0:00:11
#      -------------- ---------------------- 217.1/568.2 MB 36.4 MB/s eta 0:00:10
#      -------------- ---------------------- 219.0/568.2 MB 38.6 MB/s eta 0:00:10
#      -------------- ---------------------- 219.8/568.2 MB 32.7 MB/s eta 0:00:11
#      -------------- ---------------------- 222.8/568.2 MB 38.5 MB/s eta 0:00:09
#      -------------- ---------------------- 223.1/568.2 MB 38.5 MB/s eta 0:00:09
#      -------------- ---------------------- 225.0/568.2 MB 32.8 MB/s eta 0:00:11
#      -------------- ---------------------- 227.3/568.2 MB 38.5 MB/s eta 0:00:09
#      -------------- ---------------------- 228.1/568.2 MB 34.6 MB/s eta 0:00:10
#      --------------- --------------------- 230.9/568.2 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 231.4/568.2 MB 38.5 MB/s eta 0:00:09
#      --------------- --------------------- 233.6/568.2 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 235.6/568.2 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 236.5/568.2 MB 34.4 MB/s eta 0:00:10
#      --------------- --------------------- 239.3/568.2 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 239.7/568.2 MB 38.6 MB/s eta 0:00:09
#      --------------- --------------------- 241.9/568.2 MB 40.9 MB/s eta 0:00:08
#      --------------- --------------------- 243.9/568.2 MB 38.6 MB/s eta 0:00:09
#      --------------- --------------------- 244.6/568.2 MB 32.8 MB/s eta 0:00:10
#      ---------------- -------------------- 247.3/568.2 MB 38.5 MB/s eta 0:00:09
#      ---------------- -------------------- 248.0/568.2 MB 38.5 MB/s eta 0:00:09
#      ---------------- -------------------- 250.1/568.2 MB 36.4 MB/s eta 0:00:09
#      ---------------- -------------------- 252.2/568.2 MB 38.5 MB/s eta 0:00:09
#      ---------------- -------------------- 252.9/568.2 MB 32.7 MB/s eta 0:00:10
#      ---------------- -------------------- 255.4/568.2 MB 38.6 MB/s eta 0:00:09
#      ---------------- -------------------- 256.4/568.2 MB 38.5 MB/s eta 0:00:09
#      ---------------- -------------------- 258.5/568.2 MB 38.6 MB/s eta 0:00:09
#      ---------------- -------------------- 260.5/568.2 MB 38.6 MB/s eta 0:00:08
#      ----------------- ------------------- 261.3/568.2 MB 32.7 MB/s eta 0:00:10
#      ----------------- ------------------- 263.9/568.2 MB 38.5 MB/s eta 0:00:08
#      ----------------- ------------------- 264.7/568.2 MB 38.6 MB/s eta 0:00:08
#      ----------------- ------------------- 266.3/568.2 MB 32.7 MB/s eta 0:00:10
#      ----------------- ------------------- 268.8/568.2 MB 36.4 MB/s eta 0:00:09
#      ----------------- ------------------- 269.8/568.2 MB 32.8 MB/s eta 0:00:10
#      ----------------- ------------------- 272.6/568.2 MB 38.6 MB/s eta 0:00:08
#      ----------------- ------------------- 272.9/568.2 MB 36.4 MB/s eta 0:00:09
#      ----------------- ------------------- 275.1/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------ ------------------ 277.1/568.2 MB 40.9 MB/s eta 0:00:08
#      ------------------ ------------------ 278.0/568.2 MB 34.4 MB/s eta 0:00:09
#      ------------------ ------------------ 280.6/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------ ------------------ 281.3/568.2 MB 34.4 MB/s eta 0:00:09
#      ------------------ ------------------ 283.6/568.2 MB 36.4 MB/s eta 0:00:08
#      ------------------ ------------------ 285.4/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------ ------------------ 286.2/568.2 MB 31.2 MB/s eta 0:00:10
#      ------------------ ------------------ 288.7/568.2 MB 38.6 MB/s eta 0:00:08
#      ------------------ ------------------ 289.6/568.2 MB 36.3 MB/s eta 0:00:08
#      ------------------- ----------------- 291.9/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------- ----------------- 293.7/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------- ----------------- 294.4/568.2 MB 32.7 MB/s eta 0:00:09
#      ------------------- ----------------- 295.9/568.2 MB 38.5 MB/s eta 0:00:08
#      ------------------- ----------------- 297.9/568.2 MB 36.4 MB/s eta 0:00:08
#      ------------------- ----------------- 299.9/568.2 MB 38.6 MB/s eta 0:00:07
#      ------------------- ----------------- 301.0/568.2 MB 38.5 MB/s eta 0:00:07
#      ------------------- ----------------- 302.3/568.2 MB 32.8 MB/s eta 0:00:09
#      ------------------- ----------------- 304.6/568.2 MB 36.4 MB/s eta 0:00:08
#      ------------------- ----------------- 306.2/568.2 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 308.1/568.2 MB 38.5 MB/s eta 0:00:07
#      -------------------- ---------------- 310.3/568.2 MB 38.5 MB/s eta 0:00:07
#      -------------------- ---------------- 310.8/568.2 MB 32.7 MB/s eta 0:00:08
#      -------------------- ---------------- 313.3/568.2 MB 38.6 MB/s eta 0:00:07
#      -------------------- ---------------- 314.5/568.2 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 316.2/568.2 MB 32.8 MB/s eta 0:00:08
#      -------------------- ---------------- 318.6/568.2 MB 38.6 MB/s eta 0:00:07
#      -------------------- ---------------- 319.2/568.2 MB 32.7 MB/s eta 0:00:08
#      -------------------- ---------------- 321.9/568.2 MB 38.5 MB/s eta 0:00:07
#      --------------------- --------------- 322.8/568.2 MB 38.6 MB/s eta 0:00:07
#      --------------------- --------------- 324.6/568.2 MB 32.7 MB/s eta 0:00:08
#      --------------------- --------------- 326.9/568.2 MB 36.4 MB/s eta 0:00:07
#      --------------------- --------------- 327.4/568.2 MB 32.8 MB/s eta 0:00:08
#      --------------------- --------------- 330.1/568.2 MB 38.6 MB/s eta 0:00:07
#      --------------------- --------------- 331.1/568.2 MB 38.5 MB/s eta 0:00:07
#      --------------------- --------------- 332.7/568.2 MB 32.8 MB/s eta 0:00:08
#      --------------------- --------------- 335.2/568.2 MB 38.6 MB/s eta 0:00:07
#      --------------------- --------------- 335.8/568.2 MB 34.4 MB/s eta 0:00:07
#      ---------------------- -------------- 338.5/568.2 MB 40.9 MB/s eta 0:00:06
#      ---------------------- -------------- 339.4/568.2 MB 38.5 MB/s eta 0:00:06
#      ---------------------- -------------- 340.8/568.2 MB 32.7 MB/s eta 0:00:07
#      ---------------------- -------------- 343.2/568.2 MB 38.5 MB/s eta 0:00:06
#      ---------------------- -------------- 344.1/568.2 MB 34.6 MB/s eta 0:00:07
#      ---------------------- -------------- 346.7/568.2 MB 38.6 MB/s eta 0:00:06
#      ---------------------- -------------- 347.7/568.2 MB 38.5 MB/s eta 0:00:06
#      ---------------------- -------------- 348.9/568.2 MB 32.8 MB/s eta 0:00:07
#      ---------------------- -------------- 351.6/568.2 MB 38.5 MB/s eta 0:00:06
#      ---------------------- -------------- 352.3/568.2 MB 34.4 MB/s eta 0:00:07
#      ----------------------- ------------- 355.1/568.2 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 356.0/568.2 MB 38.6 MB/s eta 0:00:06
#      ----------------------- ------------- 358.0/568.2 MB 38.6 MB/s eta 0:00:06
#      ----------------------- ------------- 360.2/568.2 MB 38.6 MB/s eta 0:00:06
#      ----------------------- ------------- 360.7/568.2 MB 34.4 MB/s eta 0:00:07
#      ----------------------- ------------- 363.3/568.2 MB 38.5 MB/s eta 0:00:06
#      ----------------------- ------------- 364.3/568.2 MB 38.5 MB/s eta 0:00:06
#      ----------------------- ------------- 365.3/568.2 MB 31.2 MB/s eta 0:00:07
#      ----------------------- ------------- 368.0/568.2 MB 36.3 MB/s eta 0:00:06
#      ------------------------ ------------ 369.1/568.2 MB 32.7 MB/s eta 0:00:07
#      ------------------------ ------------ 371.6/568.2 MB 38.6 MB/s eta 0:00:06
#      ------------------------ ------------ 372.6/568.2 MB 38.5 MB/s eta 0:00:06
#      ------------------------ ------------ 374.4/568.2 MB 32.8 MB/s eta 0:00:06
#      ------------------------ ------------ 376.8/568.2 MB 38.5 MB/s eta 0:00:05
#      ------------------------ ------------ 377.3/568.2 MB 34.4 MB/s eta 0:00:06
#      ------------------------ ------------ 379.9/568.2 MB 38.5 MB/s eta 0:00:05
#      ------------------------ ------------ 381.0/568.2 MB 38.6 MB/s eta 0:00:05
#      ------------------------ ------------ 382.0/568.2 MB 32.7 MB/s eta 0:00:06
#      ------------------------- ----------- 384.5/568.2 MB 36.4 MB/s eta 0:00:06
#      ------------------------- ----------- 385.7/568.2 MB 32.8 MB/s eta 0:00:06
#      ------------------------- ----------- 387.7/568.2 MB 36.4 MB/s eta 0:00:05
#      ------------------------- ----------- 389.3/568.2 MB 38.5 MB/s eta 0:00:05
#      ------------------------- ----------- 390.9/568.2 MB 32.7 MB/s eta 0:00:06
#      ------------------------- ----------- 393.4/568.2 MB 40.9 MB/s eta 0:00:05
#      ------------------------- ----------- 393.9/568.2 MB 36.4 MB/s eta 0:00:05
#      ------------------------- ----------- 396.5/568.2 MB 40.9 MB/s eta 0:00:05
#      ------------------------- ----------- 397.6/568.2 MB 38.6 MB/s eta 0:00:05
#      ------------------------- ----------- 398.7/568.2 MB 32.7 MB/s eta 0:00:06
#      -------------------------- ---------- 401.6/568.2 MB 38.5 MB/s eta 0:00:05
#      -------------------------- ---------- 402.2/568.2 MB 34.6 MB/s eta 0:00:05
#      -------------------------- ---------- 404.9/568.2 MB 40.9 MB/s eta 0:00:04
#      -------------------------- ---------- 405.9/568.2 MB 38.5 MB/s eta 0:00:05
#      -------------------------- ---------- 407.3/568.2 MB 32.8 MB/s eta 0:00:05
#      -------------------------- ---------- 410.1/568.2 MB 40.9 MB/s eta 0:00:04
#      -------------------------- ---------- 410.5/568.2 MB 34.4 MB/s eta 0:00:05
#      -------------------------- ---------- 413.4/568.2 MB 40.9 MB/s eta 0:00:04
#      -------------------------- ---------- 414.2/568.2 MB 36.4 MB/s eta 0:00:05
#      --------------------------- --------- 416.1/568.2 MB 34.6 MB/s eta 0:00:05
#      --------------------------- --------- 418.4/568.2 MB 38.6 MB/s eta 0:00:04
#      --------------------------- --------- 418.8/568.2 MB 34.4 MB/s eta 0:00:05
#      --------------------------- --------- 421.1/568.2 MB 38.5 MB/s eta 0:00:04
#      --------------------------- --------- 422.5/568.2 MB 36.4 MB/s eta 0:00:05
#      --------------------------- --------- 424.0/568.2 MB 32.7 MB/s eta 0:00:05
#      --------------------------- --------- 426.6/568.2 MB 38.5 MB/s eta 0:00:04
#      --------------------------- --------- 427.1/568.2 MB 32.7 MB/s eta 0:00:05
#      --------------------------- --------- 429.2/568.2 MB 38.6 MB/s eta 0:00:04
#      ---------------------------- -------- 430.8/568.2 MB 38.5 MB/s eta 0:00:04
#      ---------------------------- -------- 432.0/568.2 MB 32.8 MB/s eta 0:00:05
#      ---------------------------- -------- 434.6/568.2 MB 36.4 MB/s eta 0:00:04
#      ---------------------------- -------- 435.0/568.2 MB 38.5 MB/s eta 0:00:04
#      ---------------------------- -------- 436.4/568.2 MB 31.2 MB/s eta 0:00:05
#      ---------------------------- -------- 439.1/568.2 MB 36.4 MB/s eta 0:00:04
#      ---------------------------- -------- 440.0/568.2 MB 32.7 MB/s eta 0:00:04
#      ---------------------------- -------- 442.6/568.2 MB 38.5 MB/s eta 0:00:04
#      ---------------------------- -------- 443.3/568.2 MB 38.6 MB/s eta 0:00:04
#      ----------------------------- ------- 445.7/568.2 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 447.4/568.2 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 448.7/568.2 MB 34.4 MB/s eta 0:00:04
#      ----------------------------- ------- 451.5/568.2 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 451.6/568.2 MB 38.5 MB/s eta 0:00:04
#      ----------------------------- ------- 454.1/568.2 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 455.7/568.2 MB 38.6 MB/s eta 0:00:03
#      ----------------------------- ------- 457.1/568.2 MB 34.4 MB/s eta 0:00:04
#      ----------------------------- ------- 459.9/568.2 MB 38.5 MB/s eta 0:00:03
#      ----------------------------- ------- 460.3/568.2 MB 34.6 MB/s eta 0:00:04
#      ------------------------------ ------ 462.3/568.2 MB 38.6 MB/s eta 0:00:03
#      ------------------------------ ------ 464.0/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 465.3/568.2 MB 34.4 MB/s eta 0:00:03
#      ------------------------------ ------ 467.9/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 468.5/568.2 MB 34.4 MB/s eta 0:00:03
#      ------------------------------ ------ 470.7/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 472.3/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 473.7/568.2 MB 34.6 MB/s eta 0:00:03
#      ------------------------------ ------ 475.4/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 476.9/568.2 MB 34.4 MB/s eta 0:00:03
#      ------------------------------- ----- 479.2/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 480.6/568.2 MB 38.6 MB/s eta 0:00:03
#      ------------------------------- ----- 481.9/568.2 MB 32.7 MB/s eta 0:00:03
#      ------------------------------- ----- 484.7/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 485.4/568.2 MB 34.4 MB/s eta 0:00:03
#      ------------------------------- ----- 487.5/568.2 MB 38.6 MB/s eta 0:00:03
#      ------------------------------- ----- 488.9/568.2 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 490.4/568.2 MB 32.8 MB/s eta 0:00:03
#      -------------------------------- ---- 493.0/568.2 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 493.7/568.2 MB 34.4 MB/s eta 0:00:03
#      -------------------------------- ---- 495.7/568.2 MB 36.4 MB/s eta 0:00:02
#      -------------------------------- ---- 497.2/568.2 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 498.6/568.2 MB 32.7 MB/s eta 0:00:03
#      -------------------------------- ---- 501.4/568.2 MB 38.6 MB/s eta 0:00:02
#      -------------------------------- ---- 501.8/568.2 MB 32.8 MB/s eta 0:00:03
#      -------------------------------- ---- 504.2/568.2 MB 38.6 MB/s eta 0:00:02
#      -------------------------------- ---- 505.5/568.2 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 507.0/568.2 MB 32.7 MB/s eta 0:00:02
#      --------------------------------- --- 509.5/568.2 MB 38.5 MB/s eta 0:00:02
#      --------------------------------- --- 509.8/568.2 MB 32.7 MB/s eta 0:00:02
#      --------------------------------- --- 512.2/568.2 MB 36.3 MB/s eta 0:00:02
#      --------------------------------- --- 513.9/568.2 MB 36.4 MB/s eta 0:00:02
#      --------------------------------- --- 515.2/568.2 MB 32.8 MB/s eta 0:00:02
#      --------------------------------- --- 517.8/568.2 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 518.0/568.2 MB 34.6 MB/s eta 0:00:02
#      --------------------------------- --- 520.6/568.2 MB 36.4 MB/s eta 0:00:02
#      ---------------------------------- -- 522.2/568.2 MB 36.4 MB/s eta 0:00:02
#      ---------------------------------- -- 523.5/568.2 MB 34.4 MB/s eta 0:00:02
#      ---------------------------------- -- 526.3/568.2 MB 40.9 MB/s eta 0:00:02
#      ---------------------------------- -- 526.8/568.2 MB 34.4 MB/s eta 0:00:02
#      ---------------------------------- -- 528.6/568.2 MB 38.5 MB/s eta 0:00:02
#      ---------------------------------- -- 530.5/568.2 MB 38.5 MB/s eta 0:00:01
#      ---------------------------------- -- 531.7/568.2 MB 34.6 MB/s eta 0:00:02
#      ---------------------------------- -- 534.0/568.2 MB 38.6 MB/s eta 0:00:01
#      ---------------------------------- -- 535.0/568.2 MB 34.4 MB/s eta 0:00:01
#      ---------------------------------- -- 537.3/568.2 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------- - 538.8/568.2 MB 38.6 MB/s eta 0:00:01
#      ----------------------------------- - 540.1/568.2 MB 34.4 MB/s eta 0:00:01
#      ----------------------------------- - 542.5/568.2 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------- - 543.3/568.2 MB 34.4 MB/s eta 0:00:01
#      ----------------------------------- - 545.5/568.2 MB 38.6 MB/s eta 0:00:01
#      ----------------------------------- - 547.1/568.2 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------- - 548.3/568.2 MB 32.8 MB/s eta 0:00:01
#      ----------------------------------- - 550.6/568.2 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------- - 551.7/568.2 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  553.6/568.2 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  555.4/568.2 MB 38.5 MB/s eta 0:00:01
#      ------------------------------------  556.6/568.2 MB 32.7 MB/s eta 0:00:01
#      ------------------------------------  558.9/568.2 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  559.6/568.2 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  561.3/568.2 MB 32.8 MB/s eta 0:00:01
#      ------------------------------------  563.7/568.2 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  565.0/568.2 MB 32.7 MB/s eta 0:00:01
#      ------------------------------------  567.6/568.2 MB 38.5 MB/s eta 0:00:01
#      ------------------------------------  568.1/568.2 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  568.1/568.2 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 28.5 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  568.2/568.2 MB 26.2 MB/s eta 0:00:01
#      -------------------------------------- 568.2/568.2 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from pt-core-news-lg==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexsandro\appdata\roaming\python\python311\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\alexsandro\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alexsandro\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.7.0,>=3.6.0->pt-core-news-lg==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %% [markdown]
# ## Iniciando com Pipeline Spacy

# %% [markdown]
# carregar modelo médio de português

# %%
import spacy

nlp = spacy.load("pt_core_news_lg")
nlp

# %%
print(type(nlp))
# Out:
# <class 'spacy.lang.pt.Portuguese'>

# %% [markdown]
# Verificar conteúdo da pipelines do nlp

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %%
documento = nlp("As Ações da Magazine Luiza S.A., Franca, Brasil, acumularam baixa de 70% ao ano. Assim já devolveram todos os ganhos do período da pandemia")

len(documento.vocab)
# Out:
# 375

# %%
print(type(documento))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %% [markdown]
# Identifica as pontuações que estão fazendo parte da palavra e as que não estão

# %%
for token in documento:
    print(token.text)
# Out:
# As
# Ações
# da
# Magazine
# Luiza
# S.A.
# ,
# Franca
# ,
# Brasil
# ,
# acumularam
# baixa
# de
# 70
# %
# ao
# ano
# .
# Assim
# já
# devolveram
# todos
# os
# ganhos
# do
# período
# da
# pandemia

# %% [markdown]
# Identifica os links tb

# %%
documento2 = nlp("Alegações extraordinárias requerem evidências extraordinárias. Carl Sagan 'https://carlsagan.com")
for token in documento2:
    print(token.text)
del documento2
# Out:
# Alegações
# extraordinárias
# requerem
# evidências
# extraordinárias
# .
# Carl
# Sagan
# '
# https://carlsagan.com

# %%
print(documento[3])
# Out:
# Magazine

# %%
print(documento[3:5])
# Out:
# Magazine Luiza

# %%
print(len(documento))
# Out:
# 29

# %% [markdown]
# ## Verificando os tipos de tokens

# %% [markdown]
# - Se é ou não Stop Word, Alfanumérico, Maiusculo, Pontuação, Número ou Sentença Inicial

# %%
print("Tokens: ", [token.text for token in documento])
print("Stop Word: ", [token.is_stop for token in documento])
print("Alfanumérico]: ", [token.is_alpha for token in documento])
print("Maiusculo: ", [token.is_upper for token in documento])
print("Pontuação: ", [token.is_punct for token in documento])
print("Número: ", [token.like_num for token in documento])
print("Sentença Inicial: ", [token.is_sent_start for token in documento])
# Out:
# Tokens:  ['As', 'Ações', 'da', 'Magazine', 'Luiza', 'S.A.', ',', 'Franca', ',', 'Brasil', ',', 'acumularam', 'baixa', 'de', '70', '%', 'ao', 'ano', '.', 'Assim', 'já', 'devolveram', 'todos', 'os', 'ganhos', 'do', 'período', 'da', 'pandemia']
# Stop Word:  [True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, True, True, False, True, True, False, True, False, True, False]
# Alfanumérico]:  [True, True, True, True, True, False, False, True, False, True, False, True, True, True, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True]
# Maiusculo:  [False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Pontuação:  [False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False]
# Número:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Sentença Inicial:  [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False]

# %% [markdown]
# Formato das strings, inclusive dos números sendo bom para datas !! Máscaras de datas

# %%
print("Tokens: ", [token.text for token in documento])
print("Formato: ", [token.shape_ for token in documento])
# Out:
# Tokens:  ['As', 'Ações', 'da', 'Magazine', 'Luiza', 'S.A.', ',', 'Franca', ',', 'Brasil', ',', 'acumularam', 'baixa', 'de', '70', '%', 'ao', 'ano', '.', 'Assim', 'já', 'devolveram', 'todos', 'os', 'ganhos', 'do', 'período', 'da', 'pandemia']
# Formato:  ['Xx', 'Xxxxx', 'xx', 'Xxxxx', 'Xxxxx', 'X.X.', ',', 'Xxxxx', ',', 'Xxxxx', ',', 'xxxx', 'xxxx', 'xx', 'dd', '%', 'xx', 'xxx', '.', 'Xxxxx', 'xx', 'xxxx', 'xxxx', 'xx', 'xxxx', 'xx', 'xxxx', 'xx', 'xxxx']

# %%
for token in documento:
    if token.like_num:
        print("Número encontrado: ", token.text)
    if token.is_punct:
        print("Pontuação encontrada: ", token.text)
# Out:
# Pontuação encontrada:  ,
# Pontuação encontrada:  ,
# Pontuação encontrada:  ,
# Número encontrado:  70
# Pontuação encontrada:  %
# Pontuação encontrada:  .

# %% [markdown]
# # Verificar as Part-of_speech que são as morfologias da palavra, ou seja, ADJ: adjetivo, ADV: advérbio entre outros
#
# ### GRAMÁTICA = sintaxe(Sujeito, frase, oração, período) U morfologia (classes gramáticais) U semântica (sentido)

# %% [markdown]
# <li>pos_ é a morfologia</li>
# <li>dep_ é dependencia</li>
# <li>lemma_ é a sintaxe</li>

# %%
for token in documento:
    print(token.text, " - ", token.pos_, " - ", token.dep_, " - ", token.lemma_, " - ", token.shape_)
# Out:
# As  -  DET  -  det  -  o  -  Xx
# Ações  -  NOUN  -  nsubj  -  Ação  -  Xxxxx
# da  -  ADP  -  case  -  de o  -  xx
# Magazine  -  PROPN  -  nmod  -  Magazine  -  Xxxxx
# Luiza  -  PROPN  -  flat:name  -  Luiza  -  Xxxxx
# S.A.  -  PROPN  -  flat:name  -  S.A.  -  X.X.
# ,  -  PUNCT  -  punct  -  ,  -  ,
# Franca  -  PROPN  -  conj  -  Franca  -  Xxxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# Brasil  -  PROPN  -  conj  -  Brasil  -  Xxxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# acumularam  -  VERB  -  ROOT  -  acumular  -  xxxx
# baixa  -  NOUN  -  obj  -  baixa  -  xxxx
# de  -  ADP  -  case  -  de  -  xx
# 70  -  NUM  -  nummod  -  70  -  dd
# %  -  SYM  -  nmod  -  %  -  %
# ao  -  ADP  -  case  -  a o  -  xx
# ano  -  NOUN  -  nmod  -  ano  -  xxx
# .  -  PUNCT  -  punct  -  .  -  .
# Assim  -  ADV  -  advmod  -  assim  -  Xxxxx
# já  -  ADV  -  advmod  -  já  -  xx
# devolveram  -  VERB  -  ROOT  -  devolver  -  xxxx
# todos  -  DET  -  det  -  todo  -  xxxx
# os  -  DET  -  det  -  o  -  xx
# ganhos  -  NOUN  -  obj  -  ganho  -  xxxx
# do  -  ADP  -  case  -  de o  -  xx
# período  -  NOUN  -  nmod  -  período  -  xxxx
# da  -  ADP  -  case  -  de o  -  xx
# pandemia  -  NOUN  -  nmod  -  pandemia  -  xxxx

# %% [markdown]
# ## DESCRIÇÃO MORFOLÓFICA DA PALAVRA

# %%
for token in documento:
    print(token.text, " - ", token.morph)
# Out:
# As  -  Definite=Def|Gender=Fem|Number=Plur|PronType=Art
# Ações  -  Gender=Fem|Number=Plur
# da  -  Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# Magazine  -  Gender=Fem|Number=Sing
# Luiza  -  Gender=Fem|Number=Sing
# S.A.  -  Number=Sing
# ,  -
# Franca  -  Gender=Fem|Number=Sing
# ,  -
# Brasil  -  Gender=Masc|Number=Sing
# ,  -
# acumularam  -  Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# baixa  -  Gender=Fem|Number=Sing
# de  -
# 70  -  NumType=Card
# %  -
# ao  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# ano  -  Gender=Masc|Number=Sing
# .  -
# Assim  -
# já  -
# devolveram  -  Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# todos  -  Gender=Masc|Number=Plur|PronType=Tot
# os  -  Definite=Def|Gender=Masc|Number=Plur|PronType=Art
# ganhos  -  Gender=Masc|Number=Plur
# do  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# período  -  Gender=Masc|Number=Sing
# da  -  Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# pandemia  -  Gender=Fem|Number=Sing

# %% [markdown]
# Trás informações um pouco mais refinadas dos tokens

# %%
for token in documento:
    print(token.text, " - ", token.tag_)
# Out:
# As  -  DET
# Ações  -  NOUN
# da  -  ADP
# Magazine  -  PROPN
# Luiza  -  PROPN
# S.A.  -  PROPN
# ,  -  PUNCT
# Franca  -  PROPN
# ,  -  PUNCT
# Brasil  -  PROPN
# ,  -  PUNCT
# acumularam  -  VERB
# baixa  -  NOUN
# de  -  ADP
# 70  -  NUM
# %  -  SYM
# ao  -  ADP
# ano  -  NOUN
# .  -  PUNCT
# Assim  -  ADV
# já  -  ADV
# devolveram  -  VERB
# todos  -  DET
# os  -  DET
# ganhos  -  NOUN
# do  -  ADP
# período  -  NOUN
# da  -  ADP
# pandemia  -  NOUN

# %% [markdown]
# ## Entidade nomeadas

# %%
for ent in documento.ents:
    print(ent.text, " - ", ent.label_)
# Out:
# Ações da Magazine Luiza S.A.  -  MISC
# Franca  -  LOC
# Brasil  -  LOC

# %% [markdown]
# ## Stop Words
# Uma boa prática é retirar as stop words (palavras vazias e sem valor semântico) sendo as defaults do modelo que estamos usando

# %%
for token in documento:
    if token.is_stop:
        print("Stop word: ", token.text)
# Out:
# Stop word:  As
# Stop word:  da
# Stop word:  de
# Stop word:  ao
# Stop word:  Assim
# Stop word:  já
# Stop word:  todos
# Stop word:  os
# Stop word:  do
# Stop word:  da

# %%
for words in nlp.Defaults.stop_words:
    print(words)
# Out:
# boa
# maior
# estiveram
# apenas
# pelo
# estivestes
# umas
# tuas
# ademais
# diz
# devem
# vossos
# máximo
# novos
# uma
# vossas
# ali
# nós
# desta
# fora
# dezanove
# grandes
# lhe
# próxima
# menor
# mil
# sabe
# povo
# treze
# de
# entre
# em
# seu
# tens
# nada
# conhecida
# cuja
# onze
# numa
# usar
# poderá
# estou
# vinda
# teus
# coisa
# nosso
# e
# próprio
# da
# forma
# fostes
# nossos
# quais
# que
# direita
# saber
# sempre
# estivemos
# obrigado
# isso
# sexta
# seis
# maiorias
# baixo
# embora
# sétimo
# dois
# já
# nenhuma
# tanta
# fazer
# muito
# algumas
# mais
# têm
# aquele
# números
# temos
# à
# me
# lado
# sim
# vens
# dizer
# aqueles
# quê
# vinte
# inicio
# nas
# demais
# talvez
# isto
# tivemos
# pôde
# vais
# o
# sexto
# nessa
# sobre
# cinco
# zero
# ou
# favor
# três
# final
# for
# no
# quarto
# disso
# estás
# desde
# nunca
# num
# questão
# oito
# pois
# corrente
# está
# sétima
# essas
# todo
# contra
# conselho
# irá
# daquela
# exemplo
# toda
# quando
# conhecido
# lugar
# menos
# pouco
# tempo
# vêm
# ontem
# outra
# tiveram
# vem
# contudo
# veja
# pontos
# ter
# esta
# então
# quinto
# primeira
# com
# tarde
# tentaram
# através
# cada
# tiveste
# ver
# tipo
# elas
# aqui
# logo
# dessa
# área
# meses
# parece
# fazemos
# um
# tente
# é
# tal
# grupo
# vários
# desse
# assim
# as
# teve
# mas
# além
# ambos
# teu
# alguns
# nova
# se
# oitavo
# des
# nossa
# onde
# mal
# fomos
# também
# dos
# dez
# sou
# possível
# cedo
# após
# nesse
# perto
# uns
# custa
# põe
# segundo
# pouca
# vezes
# depois
# usa
# estive
# essa
# terceiro
# terceira
# deste
# algo
# nem
# outras
# nos
# fazes
# maioria
# ambas
# vos
# vindo
# fazia
# mês
# pela
# nesta
# minhas
# poder
# quanto
# agora
# portanto
# sois
# momento
# sete
# tão
# último
# parte
# somos
# comprido
# lá
# estes
# quieta
# pelas
# bem
# obrigada
# atrás
# sei
# dezasseis
# tem
# faz
# sua
# dá
# dezassete
# porém
# fim
# pelos
# quem
# certamente
# faço
# enquanto
# geral
# esteve
# estará
# podem
# estão
# sem
# são
# puderam
# deverá
# novas
# seus
# muitos
# tive
# ligado
# cima
# aquela
# longe
# sistema
# quarta
# posição
# vós
# do
# para
# oitava
# deve
# todos
# bom
# como
# vão
# ainda
# dezoito
# caminho
# és
# vai
# ser
# não
# quieto
# doze
# vossa
# estava
# inclusive
# nove
# tua
# quero
# tivestes
# daquele
# dar
# porquê
# diante
# falta
# querem
# eles
# número
# qualquer
# local
# possivelmente
# cujo
# nível
# ele
# fazem
# cá
# põem
# tentei
# eu
# estado
# catorze
# apoio
# bastante
# dão
# você
# os
# estiveste
# breve
# nuns
# posso
# quinta
# naquela
# valor
# fui
# quinze
# fazeis
# iniciar
# esses
# te
# fará
# tentar
# dizem
# cento
# pode
# na
# novo
# debaixo
# seria
# aos
# este
# próximo
# tais
# até
# certeza
# ao
# foste
# fez
# foi
# relação
# eventual
# ir
# porquanto
# meus
# minha
# tanto
# naquele
# tudo
# quer
# ora
# era
# pegar
# somente
# segunda
# grande
# meio
# vosso
# estar
# vocês
# aquilo
# tenho
# ela
# antes
# apoia
# vez
# primeiro
# às
# a
# duas
# ponto
# adeus
# estas
# tendes
# sob
# esse
# porque
# dentro
# suas
# das
# qual
# todas
# apontar
# mesmo
# por
# aí
# tu
# comprida
# meu
# outros
# só
# partir
# podia
# neste
# foram
# quatro
# acerca
# nossas
# aquelas

# %% [markdown]
# Podemos adicionar novas stop words

# %%
nlp.Defaults.stop_words.add("eita")
nlp.vocab['eita'].is_stop = True

# %%
nlp.vocab['eita'].is_stop
# Out:
# True

# %%
token_lista = []

for token in documento:
    token_lista.append(token.text)

stop_lista = []

for words in nlp.Defaults.stop_words:
    stop_lista.append(words)

semstop = [word for word in token_lista if not word in stop_lista]

print(documento.text)
print(semstop)
# Out:
# As Ações da Magazine Luiza S.A., Franca, Brasil, acumularam baixa de 70% ao ano. Assim já devolveram todos os ganhos do período da pandemia
# ['As', 'Ações', 'Magazine', 'Luiza', 'S.A.', ',', 'Franca', ',', 'Brasil', ',', 'acumularam', 'baixa', '70', '%', 'ano', '.', 'Assim', 'devolveram', 'ganhos', 'período', 'pandemia']

# %% [markdown]
# ## Vocabulário
# Cada palavra tem uma hash,  um lexeme, que a identifica.

# %%
print("Hash: ", nlp.vocab.strings["dados"])
print("Hash: ", documento.vocab.strings["dados"])
print("String: ", nlp.vocab.strings[6013848609874238634])
# Out:
# Hash:  6013848609874238634
# Hash:  6013848609874238634
# String:  dados

# %%
lex = nlp.vocab["dados"]
print(lex.text, " - ", lex.orth, " - ", lex.is_alpha, " - ", lex.is_lower)
# Out:
# dados  -  6013848609874238634  -  True  -  True

# %% [markdown]
# # Embeedings

# %% [markdown]
# Embeedings são representações da palavra através de vetores e matrizes, sendo assim o tamanho do vetor tem relação com a quantidade e cada posição do vetor tem uma relação com outra palavra.

# %%
print(nlp("dados").vector.shape)
# Out:
# (300,)

# %% [markdown]
# Os pesos da palavra "dados" com outras 300 palavras, esses valores foram obitidos através do processo de treinamento do modelo.

# %%
print(nlp("dados").vector)
# Out:
# [-1.8078e+00 -2.8421e+00 -5.5345e-01 -4.0565e+00 -2.3565e+00  4.7295e+00
#  -3.3508e+00 -1.2036e+00 -5.3749e+00 -7.5768e-01 -2.0015e+00  5.3618e+00
#   2.2789e-01  1.2136e+00 -1.4418e+00 -3.0621e+00  2.2060e+00  1.1943e+00
#  -1.8689e+00 -5.9128e+00 -5.1929e-01  2.1897e+00 -2.4651e+00  1.7600e+00
#  -5.6308e+00  1.0053e+00  7.3080e-01  2.0417e-01 -6.0370e+00  1.7474e+00
#   2.0375e+00  2.7541e+00 -1.0423e+00  1.7632e+00 -1.4484e+00 -2.4344e+00
#  -8.6094e-01  1.7867e+00 -4.9920e+00 -3.1162e+00 -5.3973e-01  2.4241e+00
#   4.4410e-01 -4.7503e+00  2.1383e+00  3.8537e-01 -2.2418e+00  5.8104e+00
#  -1.1731e+00  2.4686e-02 -1.8413e+00 -5.9321e+00 -7.0872e-03 -2.3093e+00
#   5.5101e+00 -4.1795e-01  2.9754e+00  3.6709e-01 -8.0867e-01 -1.3751e+00
#   4.8132e+00 -2.2835e+00 -2.0920e-01  1.2578e+00  4.3466e+00  1.3846e+00
#  -1.5847e+00  3.3322e+00 -4.3669e+00  1.8883e+00 -1.2312e+00  3.7902e-01
#   8.6331e-01 -4.0607e+00 -1.3444e+00  4.5210e+00  2.2995e-01 -5.9245e+00
#  -2.0598e-01 -3.1810e+00 -3.8640e+00  7.2114e+00  3.1034e+00 -4.2856e+00
#   5.4147e+00 -7.2224e+00  4.3610e+00 -2.6696e+00  1.9245e+00 -2.6187e+00
#  -5.1742e+00  1.0513e-01  1.9628e+00  1.0356e+00  6.8692e+00 -7.3888e-01
#   3.8783e+00  4.1958e+00 -8.8872e+00 -1.8452e+00  5.2786e+00  4.2920e+00
#  -4.2204e-01  1.0009e+00  4.2165e-01  1.1927e+00 -8.4580e-01 -2.6577e+00
#   1.5024e+00  4.4229e-01 -2.5251e+00 -7.1781e-01  7.0878e-01  1.7207e+00
#   3.8369e+00 -1.5924e+00  2.0870e+00  4.3324e-01 -1.0600e+00  2.7058e+00
#   1.3282e+00 -7.1241e+00 -1.3663e+00 -3.0763e+00  2.7714e+00  1.3094e+00
#   1.6072e+00  3.6821e+00  5.3843e+00 -3.5457e-02 -2.9616e+00  1.5253e+00
#   2.0812e-01  6.0771e-01 -5.5709e-01  7.5687e+00 -9.1431e-01 -3.0477e+00
#   1.2046e+00  5.3871e-01  5.7112e-01  2.2039e+00 -5.1948e-02 -2.6353e+00
#  -2.8517e+00  1.8675e-01  2.1013e+00  7.5272e-01 -8.7856e+00 -1.4493e+00
#  -7.9085e-01 -1.6936e+00  1.4793e-02 -9.9357e+00  3.7818e+00 -1.7839e+00
#   1.5425e+00 -3.0899e-02 -5.1442e+00  4.2366e-01  3.2065e+00  3.9226e+00
#  -1.4392e-02  1.5862e+00  7.0632e+00  7.5689e+00 -3.4420e+00 -6.1376e+00
#   5.0851e-01 -6.3689e-01 -1.8791e-01  1.9850e+00  3.0888e+00 -3.0506e+00
#   1.1851e-01 -1.2290e+00  7.6061e+00  1.8492e-01 -2.7509e+00 -1.3448e+00
#   1.9857e+00 -2.4650e+00 -2.0810e+00  5.6084e+00 -7.3379e-01  1.1205e+00
#   1.3258e-02 -7.0243e-01  1.0118e+00  3.8903e+00 -1.2631e+00 -2.7544e+00
#   9.3134e-01  2.7516e+00 -1.6767e+00  4.5501e+00 -4.9452e-01  1.0644e+00
#  -1.2653e+00  3.9671e-01 -6.4705e+00 -7.7726e-01 -3.9283e+00  7.9536e+00
#   2.0967e+00  1.2104e+00  3.4474e+00 -2.2200e+00 -4.9974e+00  3.1827e-01
#  -1.0450e+00 -2.1353e+00  1.0529e+00 -1.6568e+00 -3.0012e+00  4.2834e+00
#   6.9626e-01  4.5401e+00 -1.7153e-01 -5.9982e-01  3.6147e+00 -3.4545e+00
#   3.6811e-01 -4.1399e+00 -1.8144e+00  2.9088e+00  8.9164e-01 -2.4783e+00
#  -3.6413e+00 -3.4140e-01 -8.0959e-01 -4.7451e+00  4.2487e+00  6.6012e+00
#  -5.1022e+00  1.5260e+00  3.5160e+00 -1.4569e+00  1.4442e+00  6.8183e+00
#  -5.0775e+00  1.0688e+00  4.8081e+00  3.6586e+00 -3.0766e+00 -8.5266e-01
#  -3.3401e+00 -5.2864e+00 -9.1773e-01 -1.8197e+00  2.0192e+00 -6.7857e+00
#  -3.6542e+00 -3.4654e+00  3.3276e+00  9.0340e-02 -3.0743e+00  3.3329e+00
#  -2.6458e+00  2.6557e-02 -4.7538e-01  2.7974e+00  5.3304e+00  2.9937e+00
#   3.8899e+00 -3.3433e+00 -3.4940e+00  2.1821e+00  8.1387e+00  3.5272e-01
#   4.8159e+00 -7.8327e-01 -1.2468e+00  5.9163e+00 -6.0636e-02 -4.3255e-01
#  -1.2690e+00 -3.2938e+00  3.2941e-02 -9.3676e-01 -7.1630e-01  1.4011e+00
#   1.8334e+00 -1.4261e+00 -1.9903e+00 -1.4721e+00  2.1466e+00 -2.0949e+00
#  -7.6855e-01 -2.8615e+00 -2.0466e+00  7.1870e-01 -1.1195e+00 -3.1117e+00
#   1.5789e-01 -4.0320e+00 -9.2665e-01 -6.2468e-01 -2.7397e+00  6.0866e-01]

# %%
print(nlp("dados são uma nova forma de ver o mundo").vector.shape)
print(nlp("dados são uma nova forma de ver o mundo").vector)
# Out:
# (300,)
# [ 0.5255733  -1.0520301  -1.0489888   0.22808893 -2.7599888   0.91837215
#  -1.6993556  -0.44524103 -2.209261   -1.2901455   0.9939946  -1.3996754
#   0.7378708  -1.6957022  -1.382649   -1.1241877   2.503239    1.3766589
#  -0.63682556  2.7080245  -0.6679023   0.7990059  -1.3761922   1.6491444
#  -0.6950322   0.69378555 -0.19840002  1.6926199  -0.3071023   0.71506053
#   0.03211441  0.27212894 -1.9055911  -1.5586021  -0.9775556   0.7999823
#  -0.9553054   0.5265729  -0.87427455 -1.2073755  -2.117481    1.2241988
#   1.5149522  -0.79308677 -1.1521667   0.13741441 -1.7882053   0.50415283
#   1.3089666   0.06542712 -0.6260744  -1.5624356  -0.707184   -1.2425367
#  -0.04237115 -0.5879791   1.7004043  -0.24798778  0.11633212 -0.55506223
#   2.0148706   0.01965364  0.92778563  2.3571968  -0.49526003  1.0151839
#   0.57112557  1.3510779  -0.3038622  -0.24523441 -0.42284998 -0.69732666
#   0.71998227  0.2875956   0.10309222 -0.6866155   2.128672    0.9791889
#  -1.4044011  -0.4600078   0.10599887  0.84635675  1.2420444   0.40497887
#   0.24567226 -2.4633954   0.30174115 -1.2952554   0.5795323  -1.899822
#  -0.74619776  2.998889    2.0798278  -0.9101444   0.27261782  0.3154811
#   3.1923532   1.315211   -3.1751957   0.03176559  1.1431444   1.6177245
#  -1.0905743   0.6142689   1.0441045  -1.0070856  -0.6415578  -0.75415665
#   0.04653723 -0.7180089  -0.09737895  0.02209669 -0.43218002 -0.37869656
#  -1.4787056  -0.8019056   2.2888644  -0.58004665 -0.35054     0.8161524
#   0.56656885 -3.1986172  -0.13080996 -0.87027764  0.19671117 -0.18788989
#   2.1433      0.5740978   0.79283893  1.1020746   0.06806201  0.14578162
#  -0.48713335 -0.9247377   0.84602445  1.326062   -0.13929449 -2.2536204
#   0.8378011   1.8202833  -2.1101756   0.01467665 -0.1241987  -0.28894553
#  -2.689321    0.35465997  1.3067889   0.78942555 -3.1275606  -0.70258003
#   1.1796956  -0.09419552 -0.39751524 -2.17274     0.00593225  0.11152443
#  -0.40126875 -0.7324776  -1.110687   -1.6154889   1.9177108   0.59479684
#  -0.9205568   1.6399556   2.1313922   0.8705971  -0.4869177  -2.5268655
#  -0.20582779 -1.351448    1.0684322   1.0798033   0.7770678  -0.88195336
#  -0.94633335 -1.6027511   2.097808   -0.44511667 -1.657932    1.3012689
#   1.4642056   0.07117888 -0.45494658  1.4971966   1.3140267  -0.48212782
#   1.0694442  -2.269592    1.3391188   1.5931556  -1.7781789  -1.465089
#   0.23485115 -2.34892     0.940096    0.5333122  -0.74473196 -1.2676699
#  -0.40783006 -0.7384778  -2.09579     2.0488043  -1.182571    0.37707764
#   1.1301712   0.28928337  1.3739567  -1.0200423   1.2103223   0.04722336
#   1.3624822  -1.2681168   1.4688356   0.8132446  -1.719049    1.8276443
#   1.0804734  -0.31434     0.88836336 -0.67704093 -1.0336466  -0.9087268
#   0.09643783 -2.5777566  -0.08628993 -0.8835056  -0.5007     -2.010551
#   0.9359345  -1.839522   -0.45124334 -1.67075     0.1972278  -0.69528896
#  -0.8587457  -0.25463215  0.23403136 -1.7613523   0.39325333  2.0033166
#   0.16394782 -0.5912411   0.4513964   0.38095444  0.9961722  -0.5356072
#  -0.24399893  1.2084801   1.047721   -0.3533555  -0.68883884 -0.05879111
#  -1.0547067  -0.9298345   0.1543278   0.22240782 -0.8161553   2.490319
#  -1.5402923   0.59167856 -1.8444476   0.68242     2.5562222   0.99307674
#   0.02924996 -0.70853776 -1.0495977   0.13625993  2.1210868   1.4868933
#   3.163472   -0.43712902 -0.514627    2.9385633  -2.2680051   0.10609888
#   2.2179537   0.63511777  0.40360793 -1.1280782  -1.7189742  -0.46922117
#   2.9208887  -0.7004363  -0.36562064  1.1512333  -1.4175044  -0.44106555
#  -0.48883343 -0.5042111   0.28768444  3.4773679  -1.2891389  -0.65457785
#   0.3968733  -1.9304742   2.1593056  -0.50640225 -1.4050981   1.26994   ]

# %% [markdown]
# ## Similaridade de sentenças
# Baseada em contexto, precisa do modelo large. Metrica usada é o cosseno valor entre 0 (menos semelhante) e 1 (mais semelhante).
# Para melhorar a performace:
# <li>sentenças menores (span)</li>
# <li>Utilizar a função sense2vec</li>
# <li>Remover stopwords, pontuações e pronomes</li>

# %%
documento1 = nlp("ela viaja regularmente de carro")
documento2 = nlp("ela viaja regularmente de avião")

documento1.similarity(documento2)
# Out:
# 0.9537205385084845

# %% [markdown]
# se trocar as palavras de posição continua mesmo número

# %%
documento1 = nlp("ela viaja regularmente de carro")
documento2 = nlp("ela avião regularmente de viaja")

documento1.similarity(documento2)
# Out:
# 0.9537206120007308

# %%
documento3 = nlp("Devenmos dizer comprimento ou cumprimento")
tokenA = documento3[2]
print(tokenA)
tokenB = documento3[4]
print(tokenB)
print(tokenA.similarity(tokenB))
# Out:
# comprimento
# cumprimento
# 0.5804340839385986

# %%
documento4 = nlp("Ele pede descrição. Ele pede discrição")
partA = documento4[0:3]
print(partA)
partB = documento4[4:7]
print(partB)
print(partA.similarity(partB))
# Out:
# Ele pede descrição
# Ele pede discrição
# 0.9630053639411926

# %% [markdown]
# ## Matcher busca padrão
# semelhante a expressão regular

# %% [markdown]
# **Temos várioas atributos e operadores dos tokens**
#
# <p>ORTH busca texto literal</p>
# <p>SHAPE busca um formato, dd digitos</p>
# <p>OP operador qualificador (? pode ser qualquer coisa)</p>

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

#adicionar pedrão de um telefone
padrao = [{"ORTH": "("},{"SHAPE":"dd"}, {"ORTH": ")"}, {"ORTH": "-", "OP":"?"},{"IS_DIGIT": True}]

matcher.add("telefone",[padrao])

documento5 = nlp("Você pode ligar para (51) - 9964656570 ou (11) 12344988")


matches = matcher(documento5)
for id, inicio, fim in matches:
    print(documento5[inicio:fim])
# Out:
# (51) - 9964656570
# (11) 12344988

# %%
documento6 = nlp("Estamos infectados com micro organismos. MICROORGANISMOS são perigosos. Não enxergamos micro-organismos")
matcher = Matcher(nlp.vocab)

padrao1 = [{"LOWER": "micro-organismos"}]
padrao2 = [{"LOWER": "microorganismos"}]
padrao3 = [{"LOWER": "micro"},{ "LOWER": "organismos"}]

matcher.add("padrao", [padrao1, padrao2, padrao3])

matches = matcher(documento6)
for id, inicio, fim in matches:
    print(documento6[inicio:fim])
# Out:
# micro organismos
# MICROORGANISMOS
# micro-organismos

# %% [markdown]
# ## Displacy para visualização

# %%
from spacy import displacy
documento.user_data['title'] = "Exemplo"
displacy.render(documento, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Exemplo</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ações da Magazine Luiza S.A.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brasil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , acumularam baixa de 70% ao ano. Assim já devolveram todos os ganhos do período da pandemia</div></span>

# %%
displacy.render(documento, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="c937efcb4d3d420181d9d852c01a20f5-0" class="displacy" width="4250" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Ações</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Magazine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Luiza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">S.A.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Franca,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Brasil,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">acumularam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">baixa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">70%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">ano.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Assim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">já</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">devolveram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">todos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">os</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">ganhos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">período</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">pandemia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c937efcb4d3d420181d9d852c01a20f5-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c937efcb4d3d420181d9d852c01a20f5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c937efcb4d3d420181d9d852c01a20f5-0-1" stroke-width="2px" d="M245,439.5 C245,2.0 1450.0,2.0 1450.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c937efcb4d3d420181d9d852c01a20f5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c937efcb4d3d420181d9d852c01a20f5-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c937efcb4d3d420181d9d852c01a20f5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="c

# %%
displacy.render(documento, style="dep", jupyter=True,
                options={'compact':True, 'distance' : 80 , 'color' : "#FFFF", 'bg': '#000000', 'font': 'Arial'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="328fdfa9b9944d2ea2e28b330a9c1c5a-0" class="displacy" width="1970" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #FFFF; background: #000000; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">Ações</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Magazine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Luiza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">S.A.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Franca,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Brasil,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">acumularam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">baixa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">70%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">ao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">ano.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">Assim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">já</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">devolveram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">todos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">os</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">ganhos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">período</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">pandemia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-0" stroke-width="2px" d="M62,202.0 62,188.66666666666666 118.0,188.66666666666666 118.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,204.0 L58,196.0 66,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-1" stroke-width="2px" d="M142,202.0 142,135.33333333333331 690.0,135.33333333333331 690.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,204.0 L138,196.0 146,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-2" stroke-width="2px" d="M222,202.0 222,188.66666666666666 278.0,188.66666666666666 278.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-328fdfa9b9944d2ea2e28b330a9c1c5a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="

# %%
displacy.render(documento, style="dep", jupyter=True,
                options={'compact':False, 'distance' : 80 , 'color' : "#FFFF", 'bg': '#000000', 'font': 'Arial'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="0ecc76225b7144d098a2cf1f9daddb50-0" class="displacy" width="1970" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #FFFF; background: #000000; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">Ações</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Magazine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Luiza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">S.A.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Franca,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Brasil,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">acumularam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">baixa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">70%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">ao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">ano.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">Assim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">já</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">devolveram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">todos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">os</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">ganhos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">período</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">pandemia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ecc76225b7144d098a2cf1f9daddb50-0-0" stroke-width="2px" d="M70,202.0 C70,162.0 110.0,162.0 110.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ecc76225b7144d098a2cf1f9daddb50-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ecc76225b7144d098a2cf1f9daddb50-0-1" stroke-width="2px" d="M150,202.0 C150,2.0 690.0,2.0 690.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ecc76225b7144d098a2cf1f9daddb50-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,204.0 L142,192.0 158,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ecc76225b7144d098a2cf1f9daddb50-0-2" stroke-width="2px" d="M230,202.0 C230,162.0 270.0,162.0 270.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ecc76225b7144d098a2cf1f9daddb50-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230,204.0 L222,192.0 238,192.0" fill="currentColor"/>
# <

# %% [markdown]
# ## Gerenciamento de Pipeline
# a pipeline roda assim que cria um documento mas tem o metodo Pipe que faz sob demanda (python Generator)

# %%
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %% [markdown]
# Remover etapa no pipeline

# %%
nlp.remove_pipe('tok2vec')
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %% [markdown]
# adicionar etapa no pipeline mudando a ordem

# %%
nlp.add_pipe('tok2vec', after='morphologizer')
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['morphologizer', 'tok2vec', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']
