# %% [markdown]
# # Abrir imagem DICOM e converte-la em np.array

# %%
# Bibliotecas
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageFilter
import glob
from random import sample

# %matplotlib inline

# %%
diretorio = 'D:\cancer de pele\data\HAM10000_images_part_1'
lista_de_fotos = os.listdir(diretorio)
print(len(lista_de_fotos))
# Out:
# 10015

# %%
dados = pd.read_csv('D:\cancer de pele\data\HAM10000_metadata.csv')
dados.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
dados.loc[(dados["dx"] == 'nv')]
# Out:
#         lesion_id      image_id  dx    dx_type   age     sex     localization
# 64    HAM_0001751  ISIC_0024698  nv  consensus  70.0    male             face
# 1210  HAM_0000559  ISIC_0024693  nv  follow_up  45.0  female  upper extremity
# 2976  HAM_0004932  ISIC_0032212  nv  follow_up  45.0  female             foot
# 2977  HAM_0004516  ISIC_0025775  nv  follow_up  45.0  female             neck
# 2978  HAM_0006510  ISIC_0029828  nv  follow_up  55.0  female  lower extremity
# ...           ...           ...  ..        ...   ...     ...              ...
# 9682  HAM_0006283  ISIC_0027924  nv  consensus  20.0    male            chest
# 9683  HAM_0000102  ISIC_0031547  nv  consensus  20.0    male             back
# 9684  HAM_0000102  ISIC_0032221  nv  consensus  20.0    male             back
# 9685  HAM_0005314  ISIC_0030693  nv  consensus  40.0    male             neck
# 9686  HAM_0003322  ISIC_0031649  nv  consensus  50.0  female             face
#
# [6705 rows x 7 columns]

# %%
for arquivos,diretorio, in os.walk(arquivo)
    lista_de_imagens = Image.open(os.path.join(diretorio, lista_de_fotos[i]))
    
print(lista_de_imagens)
# Out:
#   File "<ipython-input-6-a77a9e973a52>", line 1
#     for arquivos,diretorio, in os.walk(arquivo)
#                                                ^
# SyntaxError: invalid syntax

# %%
dire = 'D:/cancer de pele/data/HAM10000_images_part_1/'
list = glob.glob(dire + '*.jpg')

# %%
print(list)
# Out:
# ['D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024306.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024307.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024308.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024309.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024310.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024311.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024312.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024313.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024314.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024315.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024316.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024317.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024318.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_0024319.jpg', 'D:/cancer de pele/data/HAM10000_images_part_1\\ISIC_002432
# ...

# %%
reduzir = []

for i in list:
    img = plt.imread(i)
    tup = img.shape
    tup_ideal = (450, 600, 3)
    print(tup)
    if tup != tup_ideal:
        reduzir.append(i)
        print(i)

# %%
print(reduzir)

# %%
plt.imshow(img)

# %%
doen = []
doen.append(np.count_nonzero(dados['dx'] == 'akiec'))
doen.append(np.count_nonzero(dados['dx'] == 'bcc'))
doen.append(np.count_nonzero(dados['dx'] == 'mel'))
doen.append(np.count_nonzero(dados['dx'] == 'nv'))
doen.append(np.count_nonzero(dados['dx'] == 'bkl'))
doen.append(np.count_nonzero(dados['dx'] == 'df'))
doen.append(np.count_nonzero(dados['dx'] == 'vasc'))
print(doen)
print(sum(doen))
# Out:
# [327, 514, 1113, 6705, 1099, 115, 142]
# 10015

# %%
plt.title('Quantidade por doenças', fontsize=15)
plt.xlabel('Doenças', fontsize=15)
plt.ylabel('Quantidade', fontsize=15)
plt.bar(['akiec' , 'bcc' , 'mel' , 'nv' , 'bkl','df', 'vasc'],doen)
plt.show()

# %%
Ceratoses actínicas e carcinoma intraepitelial / doença de Bowen - (akiec)
carcinoma basocelular - (bcc)
lesões tipo ceratose benigna (lentigos solares / ceratoses seborreicas e líquen-plano como ceratoses) - (bkl)
dermatofibroma - (df)
melanoma - (mel)
nevos melanocíticos- (nv)
lesões vasculares (angiomas, angioqueratomas, granulomas piogênicos e hemorragia) - (vasc).

# %%
# Out:
#   File "<ipython-input-11-757b07cd6b7f>", line 2
#     for i in list
#                  ^
# SyntaxError: invalid syntax

# %%
#função para redimensionar as imagens do banco de dados
#def reduzir_tamanho_imagens(input_dir, output_dir):
#    lista_de_arquivos = os.listdir(input_dir)
#   for nome in lista_de_arquivos:
#        imag = Image.open(os.path.join(input_dir, nome))
#        redimensionada = imag.resize((512,512))
#        redimensionada.save(os.path.join(outout_dir, nome))
